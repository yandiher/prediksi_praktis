# %%
from kebanyakan_model import tumpukan_regresi
from kebanyakan_model import tumpukan_klasifikasi

# %%
import pandas as pd
data = pd.read_csv('data_select.csv')
data = data.drop('Unnamed: 0', axis=1)
data.head()
# Out:
#    overall  pace  shooting  passing  dribbling  defending  physic
# 0       94  87.0      92.0     92.0       96.0       39.0    66.0
# 1       93  90.0      93.0     82.0       89.0       35.0    78.0
# 2       92  91.0      85.0     87.0       95.0       32.0    58.0
# 3       91  91.0      83.0     86.0       94.0       35.0    66.0
# 4       91  76.0      86.0     92.0       86.0       61.0    78.0

# %%
x = data.drop(['overall'], axis=1)
y = data.overall

# %%
tumpukan_regresi(x,y)
# Out:
#                         Algorithm     Score Time
# 2             ExtraTreesRegressor  0.965227   5s
# 5   HistGradientBoostingRegressor  0.965148   1s
# 4           RandomForestRegressor  0.964846   9s
# 28                            SVR  0.964763  21s
# 27                          NuSVR  0.964266  17s
# 1                BaggingRegressor  0.960923   1s
# 25                   MLPRegressor  0.960796  45s
# 6        GaussianProcessRegressor  0.959874  79s
# 3       GradientBoostingRegressor  0.957425   2s
# 23            KNeighborsRegressor  0.945318   0s
# 29          DecisionTreeRegressor  0.926762   0s
# 0               AdaBoostRegressor  0.905567   1s
# 8                           Ridge  0.710542   0s
# 15                        LassoCV  0.710537   0s
# 18                  ARDRegression  0.710499   0s
# 19                  BayesianRidge  0.710478   0s
# 9                         RidgeCV  0.710478   0s
# 7                LinearRegression  0.710469   0s
# ...

# %%
import pandas as pd
data_baru = pd.read_csv('soccer_player_2020.csv')
pd.set_option('display.max_columns', None)
data_baru.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        170         72   Argentina  FC Barcelona       94         94
# 1        187         83    Portugal      Juventus       93         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
#
#    international_reputation  weak_foot  skill_moves   work_rate   body_type  \
# 0                         5          4            4  Medium/Low       Messi
# ...

# %%
data_class = data_baru[['team_position', 'pace','shooting','passing','dribbling','defending','physic']]

# %%
data_class.head()
# Out:
#   team_position  pace  shooting  passing  dribbling  defending  physic
# 0            RW  87.0      92.0     92.0       96.0       39.0    66.0
# 1            LW  90.0      93.0     82.0       89.0       35.0    78.0
# 2           CAM  91.0      85.0     87.0       95.0       32.0    58.0
# 3            GK   NaN       NaN      NaN        NaN        NaN     NaN
# 4            LW  91.0      83.0     86.0       94.0       35.0    66.0

# %%
data_class.isna().sum()
# Out:
# team_position     240
# pace             2036
# shooting         2036
# passing          2036
# dribbling        2036
# defending        2036
# physic           2036
# dtype: int64

# %%
data_class = data_class.dropna()

# %%
data_class.isna().sum()
# Out:
# team_position    0
# pace             0
# shooting         0
# passing          0
# dribbling        0
# defending        0
# physic           0
# dtype: int64

# %%
x = data_class.drop(['team_position'], axis=1)
y = data_class['team_position']

# %%
tumpukan_klasifikasi(x,y)
# Out:
#                          Algorithm     Score Time
# 19                   MLPClassifier  0.437208  70s
# 21                             SVC  0.427548  34s
# 6               LogisticRegression  0.426613   5s
# 20                       LinearSVC  0.425055   2s
# 3       GradientBoostingClassifier  0.424120  84s
# 18       RadiusNeighborsClassifier  0.423808   4s
# 9                  RidgeClassifier  0.423808   1s
# 16                   MultinomialNB  0.423808   0s
# 13                   CategoricalNB  0.423808   0s
# 12                     BernoulliNB  0.423496   0s
# 8                       Perceptron  0.422873   0s
# 4           RandomForestClassifier  0.418199   6s
# 5   HistGradientBoostingClassifier  0.413836  13s
# 2             ExtraTreesClassifier  0.411031   4s
# 10                   SGDClassifier  0.410097   0s
# 1                BaggingClassifier  0.344656   2s
# 17            KNeighborsClassifier  0.336865   1s
# 15                      GaussianNB  0.317856   0s
# ...
