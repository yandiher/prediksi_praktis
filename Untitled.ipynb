# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data_select.csv')

# %%
df = df.drop(labels=['Unnamed: 0'], axis=1)

# %%
x = df.drop(labels=['overall'], axis=1).values
y = df['overall'].values

# %%
from kebanyakan_model import tumpukan_regresi
tumpukan_regresi(x, y)
# Out:
#                         Algorithm     Score  Time
# 2             ExtraTreesRegressor  0.965593    5s
# 5   HistGradientBoostingRegressor  0.965113    2s
# 4           RandomForestRegressor  0.964774   10s
# 27                            SVR  0.964763   23s
# 26                          NuSVR  0.964266   19s
# 1                BaggingRegressor  0.960238    1s
# 6        GaussianProcessRegressor  0.959874  112s
# 3       GradientBoostingRegressor  0.957416    2s
# 23            KNeighborsRegressor  0.945318    0s
# 28          DecisionTreeRegressor  0.926564    0s
# 0               AdaBoostRegressor  0.905176    2s
# 8                           Ridge  0.710542    0s
# 15                        LassoCV  0.710537    1s
# 18                  ARDRegression  0.710499    0s
# 19                  BayesianRidge  0.710478    0s
# 9                         RidgeCV  0.710478    0s
# 13                         LarsCV  0.710469    0s
# 7                LinearRegression  0.710469    0s
# 17                    LassoLarsCV  0.710469    0s
# 12                           Lars  0.710469    0s
# 11                   ElasticNetCV  0.710433    0s
# 25                      LinearSVR  0.709185    0s
# 20               PoissonRegressor  0.673411    0s
# 22                 GammaRegressor  0.072774    0s
# 21               TweedieRegressor  0.072755    0s
# 24       RadiusNeighborsRegressor  0.058344    5s
# 10                     ElasticNet  0.023777    0s
# 16                      LassoLars -0.000006    0s
# 14                          Lasso -0.000006    0s

# %%
from sklearn.model_selection import train_test_split, cross_val_score
xTrain, xTest, yTrain, yTest = train_test_split(x, y, train_size=0.8, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor()

# %%
print(cross_val_score(estimator=reg, X=xTrain, y=yTrain, cv=5).mean())
# Out:
# 0.9641393046570583
